# %%
#Specification of CFG
import nltk 

grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> Det N | Det N PP
VP -> V | V NP | V NP PP
PP -> P NP

Det -> 'a' | 'an' | 'the'
N -> 'man' | 'park' | 'dog' | 'telescope'
V -> 'saw' | 'walked'
P -> 'in' | 'with'
""")

# %%
str = "the man saw a dog in the park with a telescope"

from nltk.parse import RecursiveDescentParser

#Using a top-down parser
rdstr = RecursiveDescentParser(grammar)

#Print each of the trees 
for tree in rdstr.parse(str.split()):
    print(tree)
# Out:
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP
#       (Det a)
#       (N dog)
#       (PP
#         (P in)
#         (NP
#           (Det the)
#           (N park)
#           (PP (P with) (NP (Det a) (N telescope))))))))
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP (Det a) (N dog))
#     (PP
#       (P in)
#       (NP
#         (Det the)
#         (N park)
#         (PP (P with) (NP (Det a) (N telescope)))))))
# (S
#   (NP (Det the) (N man))
#   (VP
#     (V saw)
#     (NP (Det a) (N dog) (PP (P in) (NP (Det the) (N park))))
#     (PP (P with) (NP (Det a) (N telescope)))))

# %%
#The last tree looks like this - 
tree
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     802                 ).split()
#     803             )
# --> 804             with open(out_path, 'rb') as sr:
#     805                 res = sr.read()
#     806             os.remove(in_path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\dell\\AppData\\Local\\Temp\\tmp9vpho3oy.png'
# Tree('S', [Tree('NP', [Tree('Det', ['the']), Tree('N', ['man'])]), Tree('VP', [Tree('V', ['saw']), Tree('NP', [Tree('Det', ['a']), Tree('N', ['dog']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['the']), Tree('N', ['park'])])])]), Tree('PP', [Tree('P', ['with']), Tree('NP', [Tree('Det', ['a']), Tree('N', ['telescope'])])])])])

# %%
nltk.app.rdparser()
# once the recursive descent parser application opens, 
# you can edit the 'Text' and 'Grammar' according to your requirements

# %%
#Specification of CFG
import nltk 

grammar = nltk.CFG.fromstring("""
S -> NP VP
NP ->  NP PP | DT NN
VP -> V JJ
PP -> IN NP

DT -> 'The' | 'the'
NN -> 'work' | 'analyst'
V -> 'is'
JJ -> 'good'
IN -> 'of'
""")

# %%
str1 = "The work of the analyst is good"
from nltk.parse import RecursiveDescentParser

#Using a top-down parser
rdstr = RecursiveDescentParser(grammar)

#Print each of the trees 
for tree in rdstr.parse(str1.split()):
    print(tree)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-13-26a7cddd72c1> in <module>
#       6
#       7 #Print each of the trees
# ----> 8 for tree in rdstr.parse(str1.split()):
#       9     print(tree)
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ...
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     229                     self._trace_expand(newtree, new_frontier, production)
#     230                 for result in self._parse(
# --> 231                     remaining_text, newtree, new_frontier + frontier[1:]
#     232                 ):
#     233                     yield result
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _parse(self, remaining_text, tree, frontier)
#     126         # If the next element on the frontier is a tree, expand it.
#     127         elif isinstance(tree[frontier[0]], Tree):
# --> 128             for result in self._expand(remaining_text, tree, frontier):
#     129                 yield result
#     130
#
# ~\Anaconda3\lib\site-packages\nltk\parse\recursivedescent.py in _expand(self, remaining_text, tree, frontier, production)
#     221                     newtree = subtree
#     222                 else:
# --> 223                     newtree = tree.copy(deep=True)
#     224                     newtree[frontier[0]] = subtree
#     225                 new_frontier = [
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in copy(self, deep)
#     561             return type(self)(self._label, self)
#     562         else:
# --> 563             return type(self).convert(self)
#     564
#     565     def _frozen_class(self):
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in convert(cls, tree)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in <listcomp>(.0)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# ... last 2 frames repeated, from the frame below ...
#
# ~\Anaconda3\lib\site-packages\nltk\tree.py in convert(cls, tree)
#     552         """
#     553         if isinstance(tree, Tree):
# --> 554             children = [cls.convert(child) for child in tree]
#     555             return cls(tree._label, children)
#     556         else:
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ## Above is an example of left  recursion problem

# %% [markdown]
# ## Solution

# %%
#Specification of CFG
import nltk 

grammar = nltk.CFG.fromstring("""
S -> NP VP
NP ->  NP PP | DT NN
NP -> DT NN (NP1)

NP1 -> PP NP1| ε

VP -> V JJ
PP -> IN NP

DT -> 'The' | 'the'
NN -> 'work' | 'analyst'
V -> 'is'
JJ -> 'good'
IN -> 'of'
""")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\grammar.py in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1348                 # expand out the disjunctions on the RHS
# -> 1349                 productions += _read_production(line, nonterm_parser, probabilistic)
#    1350         except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\nltk\grammar.py in _read_production(line, nonterm_parser, probabilistic)
#    1287         else:
# -> 1288             nonterm, pos = nonterm_parser(line, pos)
#    1289             rhsides[-1].append(nonterm)
#
# ~\Anaconda3\lib\site-packages\nltk\grammar.py in standard_nonterm_parser(string, pos)
#    1365     if not m:
# -> 1366         raise ValueError('Expected a nonterminal, found: ' + string[pos:])
#    1367     return (Nonterminal(m.group(1)), m.end())
#
# ValueError: Expected a nonterminal, found: (NP1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-aba8a132fbc7> in <module>
#      17 JJ -> 'good'
#      18 IN -> 'of'
# ---> 19 """)
#
# ~\Anaconda3\lib\site-packages\nltk\grammar.py in fromstring(cls, input, encoding)
#     564         """
#     565         start, productions = read_grammar(
# --> 566             input, standard_nonterm_parser, encoding=encoding
#     567         )
#     568         return cls(start, productions)
#
# ~\Anaconda3\lib\site-packages\nltk\grammar.py in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1349                 productions += _read_production(line, nonterm_parser, probabilistic)
#    1350         except ValueError as e:
# -> 1351             raise ValueError('Unable to parse line %s: %s\n%s' % (linenum + 1, line, e))
#    1352
#    1353     if not productions:
#
# ValueError: Unable to parse line 4: NP -> DT NN (NP1)
# Expected a nonterminal, found: (NP1)

# %%
str1 = "The work of the analyst is good"
from nltk.parse import RecursiveDescentParser

#Using a top-down parser
rdstr = RecursiveDescentParser(grammar)

#Print each of the trees 
for tree in rdstr.parse(str1.split()):
    print(tree)
